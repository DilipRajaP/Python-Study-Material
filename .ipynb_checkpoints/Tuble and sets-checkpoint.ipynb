# %%
#tuple

# %%
a = (9,9,5,4,6,3,2,1,1,1)

# %%
a
# Out:
# (9, 9, 5, 4, 6, 3, 2, 1, 1, 1)

# %%
len(a)
# Out:
# 10

# %%
a[5]
# Out:
# 3

# %%
#tuple is unchangeable,can get duplicates,ordered

# %%
#sets{}

# %%
b = {1,1,2,5,4,6,6,8,7,9,3,2,3,3}

# %%
b
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
#sets remove duplicates

# %%
len(b)
# Out:
# 9

# %%
b.add(20)

# %%
b
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 20}

# %%
b.pop()
# Out:
# 1

# %%
b
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9, 20}

# %%
#set is unordered,no duplicates,
