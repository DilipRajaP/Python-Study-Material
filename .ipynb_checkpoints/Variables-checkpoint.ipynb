# %%
a = 10

# %%
a
# Out:
# 10

# %%
b = 6

# %%
b
# Out:
# 6

# %%
name = "DilipRaja"

# %%
name
# Out:
# 'DilipRaja'

# %%
name[5]
# Out:
# 'R'

# %%
name[:5]
# Out:
# 'Dilip'

# %%
name[5:]
# Out:
# 'Raja'

# %%
len(name)
# Out:
# 9
