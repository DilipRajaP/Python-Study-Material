# %%
a = [1,2,3,1,2,3,4,5,6]

# %%
a
# Out:
# [1, 2, 3, 1, 2, 3, 4, 5, 6]

# %%
len(a)
# Out:
# 9

# %%
a[5]
# Out:
# 3

# %%
a.append(10)

# %%
a
# Out:
# [1, 2, 3, 1, 2, 3, 4, 5, 6, 10]

# %%
a.insert(2,555)

# %%
a
# Out:
# [1, 2, 555, 3, 1, 2, 3, 4, 5, 6, 10]

# %%
a.pop()
# Out:
# 10

# %%
a
# Out:
# [1, 2, 555, 3, 1, 2, 3, 4, 5, 6]

# %%
a.pop(2)
# Out:
# 555

# %%
a
# Out:
# [1, 2, 3, 1, 2, 3, 4, 5, 6]

# %%
len(a)
# Out:
# 9
