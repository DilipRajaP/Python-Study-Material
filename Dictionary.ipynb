# %%
data = {1:"Dilip",2:"Raja",3:"DilipRaja"}

# %%
data
# Out:
# {1: 'Dilip', 2: 'Raja', 3: 'DilipRaja'}

# %%
data[3]
# Out:
# 'DilipRaja'

# %%
data.get(2)
# Out:
# 'Raja'

# %%
data.get(5,"No matches Founded")
# Out:
# 'No matches Founded'

# %%
data.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
data.values()
# Out:
# dict_values(['Dilip', 'Raja', 'DilipRaja'])

# %%
data[4] = "RajaDilip"

# %%
data
# Out:
# {1: 'Dilip', 2: 'Raja', 3: 'DilipRaja', 4: 'RajaDilip'}

# %%
data.pop(1)
# Out:
# 'Dilip'

# %%
data
# Out:
# {2: 'Raja', 3: 'DilipRaja', 4: 'RajaDilip'}

# %%
len(data)
# Out:
# 3

# %%
names = {"dilip":"Raja","Diwin":"Bharathi","Vijay":"Joseph"}

# %%
names
# Out:
# {'dilip': 'Raja', 'Diwin': 'Bharathi', 'Vijay': 'Joseph'}

# %%
names["Vijay"]
# Out:
# 'Joseph'

# %%
names["Vijay"] = "Bigil"

# %%
names
# Out:
# {'dilip': 'Raja', 'Diwin': 'Bharathi', 'Vijay': 'Bigil'}

# %%
Words = {"dilip":["Raja","Dilip"],"Diwin":"Bharathi","Vijay":{1:"Joseph",2:"Bigil",3:"Master"}}

# %%
Words
# Out:
# {'dilip': ['Raja', 'Dilip'],
#  'Diwin': 'Bharathi',
#  'Vijay': {1: 'Joseph', 2: 'Bigil', 3: 'Master'}}

# %%
Words["Vijay"][3]
# Out:
# 'Master'

# %%
Words["dilip"][1]
# Out:
# 'Dilip'

# %%
Words["dilip"] = "DilipRaja"

# %%
Words
# Out:
# {'dilip': 'DilipRaja',
#  'Diwin': 'Bharathi',
#  'Vijay': {1: 'Joseph', 2: 'Bigil', 3: 'Master'}}

# %%
Words["dilip"][:5]
# Out:
# 'Dilip'

# %%
Words["Vijay"][3][:2]
# Out:
# 'Ma'
