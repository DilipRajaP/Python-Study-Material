# %%
1 + 1 #Add
# Out:
# 2

# %%
1-6 #sub
# Out:
# -5

# %%
9/3    #Division with flot
# Out:
# 3.0

# %%
9//3    #division without
# Out:
# 3

# %%
9*1   #Multplies
# Out:
# 9

# %%
9%5 #mod
# Out:
# 4

# %%
print("Dilip")
# Out:
# Dilip

# %%
#\n
print("Dilip \n Raja")
# Out:
# Dilip
#  Raja

# %%
#\

print('this is dilip\'s pen')
# Out:
# this is dilip's pen

# %%
x = 1

# %%
y = 5

# %%
x * y
# Out:
# 5

# %%
_ + 10
# Out:
# 15

# %%
# _ it mean last output
